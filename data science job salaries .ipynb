# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('ds_salaries.csv')

# %%
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
df.loc[(df['salary_in_usd']>50000)] #will show the salaries that ar more than 50000.
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 4             4       2020               SE              FT
# 5             5       2020               EN              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
df.shape
# Out:
# (607, 12)

# %%
df.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
df.loc[(df['salary_in_usd']%2==0)] #modulus operation at  salary_in_usd
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# 5             5       2020               EN              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 1    Machine Learning Scientist  260000             USD         260000
# 2             Big Data Engineer   85000             GBP         109024
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
data_analyst=df.loc[(df['job_title']=='Data Analyst')]

# %%
analyst_salary=data_analyst[['salary', 'company_size','job_title']]

# %%
high_and_low_salary=analyst_salary.max(),analyst_salary.min()

# %%
type(high_and_low_salary)
# Out:
# tuple

# %%
newdf=pd.DataFrame(high_and_low_salary)

# %%
newdf
# Out:
#    salary company_size     job_title
# 0  450000            S  Data Analyst
# 1    8000            L  Data Analyst

# %%
newdf.to_csv('Data_analyst')

# %%
data_A=pd.read_csv('Data_analyst')

# %%
data_A
# Out:
#    Unnamed: 0  salary company_size     job_title
# 0           0  450000            S  Data Analyst
# 1           1    8000            L  Data Analyst

# %%
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
data_engineer=df.loc[(df['job_title']=='Data Engineer')]

# %%
data_engineer
# Out:
#      Unnamed: 0  work_year experience_level employment_type      job_title  \
# 16           16       2020               EN              FT  Data Engineer
# 22           22       2020               SE              FT  Data Engineer
# 27           27       2020               SE              FT  Data Engineer
# 35           35       2020               MI              FT  Data Engineer
# 43           43       2020               MI              FT  Data Engineer
# ..          ...        ...              ...             ...            ...
# 579         579       2022               SE              FT  Data Engineer
# 582         582       2022               SE              FT  Data Engineer
# 583         583       2022               SE              FT  Data Engineer
# 602         602       2022               SE              FT  Data Engineer
# 603         603       2022               SE              FT  Data Engineer
#
# ...

# %%
main_data=data_engineer[['job_title','company_location']]

# %%
results=main_data.sort_values(by='company_location').value_counts()

# %%
results
# Out:
# job_title      company_location
# Data Engineer  US                  85
#                GB                  20
#                GR                   5
#                DE                   4
#                ES                   4
#                FR                   2
#                IN                   2
#                NL                   2
#                TR                   2
#                AT                   1
#                IR                   1
#                JP                   1
#                MT                   1
#                MX                   1
#                PL                   1
# dtype: int64

# %%
datanew=pd.DataFrame(results)

# %%
datanew.to_csv('data_engineer')

# %%
data_E=pd.read_csv('data_engineer')

# %%
data_E
# Out:
#         job_title company_location   0
# 0   Data Engineer               US  85
# 1   Data Engineer               GB  20
# 2   Data Engineer               GR   5
# 3   Data Engineer               DE   4
# 4   Data Engineer               ES   4
# 5   Data Engineer               FR   2
# 6   Data Engineer               IN   2
# 7   Data Engineer               NL   2
# 8   Data Engineer               TR   2
# 9   Data Engineer               AT   1
# 10  Data Engineer               IR   1
# 11  Data Engineer               JP   1
# 12  Data Engineer               MT   1
# 13  Data Engineer               MX   1
# 14  Data Engineer               PL   1

# %%
col_new=pd.concat([data_E,data_A], axis=0)

# %%
col_new
# Out:
#         job_title company_location     0  Unnamed: 0    salary company_size
# 0   Data Engineer               US  85.0         NaN       NaN          NaN
# 1   Data Engineer               GB  20.0         NaN       NaN          NaN
# 2   Data Engineer               GR   5.0         NaN       NaN          NaN
# 3   Data Engineer               DE   4.0         NaN       NaN          NaN
# 4   Data Engineer               ES   4.0         NaN       NaN          NaN
# 5   Data Engineer               FR   2.0         NaN       NaN          NaN
# 6   Data Engineer               IN   2.0         NaN       NaN          NaN
# 7   Data Engineer               NL   2.0         NaN       NaN          NaN
# 8   Data Engineer               TR   2.0         NaN       NaN          NaN
# 9   Data Engineer               AT   1.0         NaN       NaN          NaN
# 10  Data Engineer               IR   1.0         NaN       NaN          NaN
# ...

# %%
new_col=col_new.rename(columns={'salary':'salary_range','company_location':'region','0':'jobs'})

# %%
new_col
# Out:
#         job_title region  jobs  Unnamed: 0  salary_range company_size
# 0   Data Engineer     US  85.0         NaN           NaN          NaN
# 1   Data Engineer     GB  20.0         NaN           NaN          NaN
# 2   Data Engineer     GR   5.0         NaN           NaN          NaN
# 3   Data Engineer     DE   4.0         NaN           NaN          NaN
# 4   Data Engineer     ES   4.0         NaN           NaN          NaN
# 5   Data Engineer     FR   2.0         NaN           NaN          NaN
# 6   Data Engineer     IN   2.0         NaN           NaN          NaN
# 7   Data Engineer     NL   2.0         NaN           NaN          NaN
# 8   Data Engineer     TR   2.0         NaN           NaN          NaN
# 9   Data Engineer     AT   1.0         NaN           NaN          NaN
# 10  Data Engineer     IR   1.0         NaN           NaN          NaN
# 11  Data Engineer     JP   1.0         NaN           NaN          NaN
# ...

# %%
final_re=new_col.drop('Unnamed: 0',axis=1)

# %%
final_re
# Out:
#         job_title region  jobs  salary_range company_size
# 0   Data Engineer     US  85.0           NaN          NaN
# 1   Data Engineer     GB  20.0           NaN          NaN
# 2   Data Engineer     GR   5.0           NaN          NaN
# 3   Data Engineer     DE   4.0           NaN          NaN
# 4   Data Engineer     ES   4.0           NaN          NaN
# 5   Data Engineer     FR   2.0           NaN          NaN
# 6   Data Engineer     IN   2.0           NaN          NaN
# 7   Data Engineer     NL   2.0           NaN          NaN
# 8   Data Engineer     TR   2.0           NaN          NaN
# 9   Data Engineer     AT   1.0           NaN          NaN
# 10  Data Engineer     IR   1.0           NaN          NaN
# 11  Data Engineer     JP   1.0           NaN          NaN
# 12  Data Engineer     MT   1.0           NaN          NaN
# 13  Data Engineer     MX   1.0           NaN          NaN
# 14  Data Engineer     PL   1.0           NaN          NaN
# ...
